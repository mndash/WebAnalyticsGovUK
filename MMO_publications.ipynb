# %%
#location to save our ouput file
display(dbutils.fs.ls('/mnt/lab/unrestricted/muhammed.njie@marinemanagement.org.uk'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/lab/unrestricted/muhammed.njie@marinemanagement.org.uk/chips_index.parquet</td><td>chips_index.parquet</td><td>112178</td><td>1764237190000</td></tr><tr><td>dbfs:/mnt/lab/unrestricted/muhammed.njie@marinemanagement.org.uk/published/</td><td>published/</td><td>0</td><td>1764764421000</td></tr></tbody></table></div>

# %%
import pandas as pd
parquet_path = '/mnt/lab/unrestricted/muhammed.njie@marinemanagement.org.uk/published/mmo_published_guidance.parquet'
df = pd.read_parquet(f"/dbfs{parquet_path}")
df = df.apply(lambda col: col.str.rstrip() if col.dtype == "object" else col)
df.to_parquet(f"/dbfs{parquet_path}", index=False)
df.head()
# Out:
#                                                Title  ...      Last Updated
# 0                      Create a UK catch certificate  ...       2 July 2025
# 1                  Fishing vessel licence variations  ...  27 November 2025
# 2                     Get permission for marine work  ...  18 November 2025
# 3               Marine licensing exempted activities  ...  18 November 2025
# 4  EU IUU Regulation Changes 2026: Catch Certific...  ...   30 October 2025
#
# [5 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Title', 'URL', 'Last Updated'], dtype='object')

# %%
import pandas as pd
parquet_path = "/mnt/lab/unrestricted/muhammed.njie@marinemanagement.org.uk/published/classified_publications.parquet"
df = pd.read_parquet(f"/dbfs{parquet_path}")
df = df.apply(lambda col: col.str.rstrip() if col.dtype == "object" else col)
df.to_parquet(f"/dbfs{parquet_path.rstrip('.parquet')}_cleaned.parquet", index=False)
df.head()
# Out:
#                                                Title  ...                  Assigned_Department
# 0                      Create a UK catch certificate  ...                Stats – Sea fisheries
# 1                  Fishing vessel licence variations  ...  Fishing vessel licensing Team (FVL)
# 2                     Get permission for marine work  ...                    Conservative team
# 3               Marine licensing exempted activities  ...                              Funding
# 4  EU IUU Regulation Changes 2026: Catch Certific...  ...                                  IIU
#
# [5 rows x 6 columns]

# %%
df.to_csv("classified_publications.csv", index=False)

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated'].dt.day_name().value_counts(normalize=True)
# Out:
# Tuesday      0.229032
# Thursday     0.225806
# Wednesday    0.222581
# Monday       0.170968
# Friday       0.151613
# Name: Last Updated, dtype: float64
